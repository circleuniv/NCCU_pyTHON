# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2)
# Out:
# 1.0

# %%
plot([-2,10,3,13,5])

# %%
randn(10)
# Out:
# array([-0.02308912, -0.72427609, -1.70944905,  0.52664411, -1.70708145,
#        -0.70018266,  0.49748974, -1.34389565,  0.42169205, -0.90398769])

# %%
plot(randn(100))

# %%
plot([-2,1,2.7,3.3],[3,-5,6,0])
