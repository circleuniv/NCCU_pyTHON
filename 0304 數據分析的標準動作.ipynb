# %% [markdown]
# # 每一次要數據分析前 必引入的三種套件

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
np.pi
# Out:
# 3.141592653589793

# %%
plt.plot([3,-4,7,0,9,10,-3,6])

# %%
plt.plot(np.random.randn(100))

# %%
np.random.randn?
